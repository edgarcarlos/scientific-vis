# %% [markdown]
# ASSIGNMENT 2 ( DATA INTEGRATION )

# %% [markdown]
# Caricamento datasets

# %%
import pandas as pd

# ======================
# 1. Matrici GO (gene x go-term)
# ======================

bp = pd.read_csv("gene_go_matrix_propT_rel-is_a-part_of_ont-BP.csv", index_col=0)
cc = pd.read_csv("gene_go_matrix_propT_rel-is_a-part_of_ont-CC.csv", index_col=0)
mf = pd.read_csv("gene_go_matrix_propT_rel-is_a-part_of_ont-MF.csv", index_col=0)

# ======================
# 2. Matrice HPO (gene x hpo-term)
# ======================
hpo = pd.read_csv("gene_hpo_matrix_binary_withAncestors_namespace_Phenotypic abnormality.csv",
                  index_col=0)

# ======================
# 3. Tabelle profondità GO terms
# ======================
depth_bp = pd.read_csv("goterm_depth_propT_rel-is_a-part_of_ont-BP.csv")
depth_cc = pd.read_csv("goterm_depth_propT_rel-is_a-part_of_ont-CC.csv")
depth_mf = pd.read_csv("goterm_depth_propT_rel-is_a-part_of_ont-MF.csv")

# ======================
# Controllo veloce
# ======================
bp.shape, cc.shape, mf.shape, hpo.shape
# Out:
# ((5183, 9873), (5183, 1478), (5183, 3258), (5183, 10185))

# %% [markdown]
# Visualizzzione distribuzione profondità

# %%
import matplotlib.pyplot as plt

# Estraggo le profondità come Serie (già coerenti con il tuo codice)
depth_bp_series = depth_bp.iloc[0, 2:].astype(int)
depth_cc_series = depth_cc.iloc[0, 2:].astype(int)
depth_mf_series = depth_mf.iloc[0, 2:].astype(int)


def plot_depth_distribution(depth_series, title):
    depth_counts = depth_series.value_counts().sort_index()

    plt.figure(figsize=(6,4))
    depth_counts.plot(kind="bar")
    plt.xlabel("Profondità GO")
    plt.ylabel("Numero di GO terms")
    plt.title(title)
    plt.xticks(rotation=0)

    plt.tight_layout()
    plt.show()
    #print(depth_counts)  # così vedi anche i numeri a console

# BP
plot_depth_distribution(depth_bp_series, "Distribuzione profondità GO — BP")

# CC
plot_depth_distribution(depth_cc_series, "Distribuzione profondità GO — CC")

# MF
plot_depth_distribution(depth_mf_series, "Distribuzione profondità GO — MF")

# %% [markdown]
# Filtraggio dei GO terms con profondità : 3

# %%
import pandas as pd

# ======================
# STEP 1 — Scegli la soglia di profondità
# ======================
DEPTH_THRESHOLD = 3   # puoi aumentare a 4 se vuoi solo termini molto specifici
#DEPTH_THRESHOLDS = 4

# ======================
# STEP 2 — Seleziona i GO terms con profondità sufficiente
# ======================

# The depth dataframes have GO terms as column headers (from index 2 onwards)
# and their depths in the first row (index 0) from index 2 onwards.
# We need to extract this information into a Series for easier filtering.

# For depth_bp:
depth_bp_series = depth_bp.iloc[0, 2:].astype(int) # Convert depths to int
valid_bp_terms = depth_bp_series[depth_bp_series >= DEPTH_THRESHOLD].index.tolist()

# For depth_cc:
depth_cc_series = depth_cc.iloc[0, 2:].astype(int) # Convert depths to int
valid_cc_terms = depth_cc_series[depth_cc_series >= DEPTH_THRESHOLD].index.tolist()

# For depth_mf:
depth_mf_series = depth_mf.iloc[0, 2:].astype(int) # Convert depths to int
valid_mf_terms = depth_mf_series[depth_mf_series >= DEPTH_THRESHOLD].index.tolist()


# ======================
# STEP 3 — Filtra le matrici GO sulle colonne valide
# ======================

bp_filtered = bp.loc[:, bp.columns.isin(valid_bp_terms)]
cc_filtered = cc.loc[:, cc.columns.isin(valid_cc_terms)]
mf_filtered = mf.loc[:, mf.columns.isin(valid_mf_terms)]


# ======================
# STEP 4 — Rimuovi eventuali colonne completamente vuote
# ======================

bp_filtered = bp_filtered.loc[:, bp_filtered.sum(axis=0) > 0]
cc_filtered = cc_filtered.loc[:, cc_filtered.sum(axis=0) > 0]
mf_filtered = mf_filtered.loc[:, mf_filtered.sum(axis=0) > 0]


# ======================
# STEP 5 — Output di verifica
# ======================

print("Filtraggio completato:\n")
print(f"BP: {bp.shape[1]} → {bp_filtered.shape[1]} GO terms mantenuti")
print(f"CC: {cc.shape[1]} → {cc_filtered.shape[1]} GO terms mantenuti")
print(f"MF: {mf.shape[1]} → {mf_filtered.shape[1]} GO terms mantenuti")
# Out:
# Filtraggio completato:
#
# BP: 9873 → 9439 GO terms mantenuti
# CC: 1478 → 1193 GO terms mantenuti
# MF: 3258 → 3042 GO terms mantenuti

# %% [markdown]
# DATA INTEGRATION CON MOFA

# %% [markdown]
# import mofapy

# %%
pip install  mofax
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting mofapy2
#   Downloading mofapy2-0.7.2-py3-none-any.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 2.7 MB/s eta 0:00:01
# Collecting mofax
#   Downloading mofax-0.3.7-py3-none-any.whl (37 kB)
# Requirement already satisfied: pandas in /Users/edgardjossa/Library/Python/3.9/lib/python/site-packages (from mofapy2) (2.3.0)
# Requirement already satisfied: numpy in /Users/edgardjossa/Library/Python/3.9/lib/python/site-packages (from mofapy2) (2.0.2)
# Collecting scipy<2,>=1
#   Downloading scipy-1.13.1-cp39-cp39-macosx_12_0_arm64.whl (30.3 MB)
#      |████████████████████████████████| 30.3 MB 3.1 MB/s eta 0:00:01
# Collecting anndata>0.8
#   Downloading anndata-0.10.9-py3-none-any.whl (128 kB)
#      |████████████████████████████████| 128 kB 1.8 MB/s eta 0:00:01
# Collecting scikit-learn<2,>=1
#   Downloading scikit_learn-1.6.1-cp39-cp39-macosx_12_0_arm64.whl (11.1 MB)
#      |████████████████████████████████| 11.1 MB 2.8 MB/s eta 0:00:01
# Collecting h5py<4,>=3
#   Downloading h5py-3.14.0-cp39-cp39-macosx_11_0_arm64.whl (2.8 MB)
#      |████████████████████████████████| 2.8 MB 2.4 MB/s eta 0:00:01
# Collecting matplotlib>=3.1.0
#   Downloading matplotlib-3.9.4-cp39-cp39-macosx_11_0_arm64.whl (7.8 MB)
#      |████████████████████████████████| 7.8 MB 3.5 MB/s eta 0:00:01
# Collecting seaborn>=0.9.0
#   Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#      |████████████████████████████████| 294 kB 2.3 MB/s eta 0:00:01
# Collecting natsort
#   Downloading natsort-8.4.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: packaging>=20.0 in /Users/edgardjossa/Library/Python/3.9/lib/python/site-packages (from anndata>0.8->mofapy2) (25.0)
# Collecting array-api-compat!=1.5,>1.4
#   Downloading array_api_compat-1.11.2-py3-none-any.whl (53 kB)
#      |████████████████████████████████| 53 kB 1.4 MB/s eta 0:00:01
# Requirement already satisfied: exceptiongroup in /Users/edgardjossa/Library/Python/3.9/lib/python/site-packages (from anndata>0.8->mofapy2) (1.3.0)
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.3.0-cp39-cp39-macosx_11_0_arm64.whl (249 kB)
#      |████████████████████████████████| 249 kB 3.1 MB/s eta 0:00:01
# Collecting pillow>=8
#   Downloading pillow-11.3.0-cp39-cp39-macosx_11_0_arm64.whl (4.7 MB)
#      |████████████████████████████████| 4.7 MB 2.7 MB/s eta 0:00:01
# Collecting importlib-resources>=3.2.0
#   Downloading importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Collecting pyparsing>=2.3.1
#   Downloading pyparsing-3.2.5-py3-none-any.whl (113 kB)
#      |████████████████████████████████| 113 kB 1.9 MB/s eta 0:00:01
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.60.1-cp39-cp39-macosx_10_9_universal2.whl (2.8 MB)
#      |████████████████████████████████| 2.8 MB 1.8 MB/s eta 0:00:01
# Collecting cycler>=0.10
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/edgardjossa/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.1.0->mofax) (2.9.0.post0)
# Collecting kiwisolver>=1.3.1
#   Downloading kiwisolver-1.4.7-cp39-cp39-macosx_11_0_arm64.whl (64 kB)
#      |████████████████████████████████| 64 kB 3.2 MB/s eta 0:00:01
# Requirement already satisfied: zipp>=3.1.0 in /Users/edgardjossa/Library/Python/3.9/lib/python/site-packages (from importlib-resources>=3.2.0->matplotlib>=3.1.0->mofax) (3.23.0)
# Requirement already satisfied: tzdata>=2022.7 in /Users/edgardjossa/Library/Python/3.9/lib/python/site-packages (from pandas->mofapy2) (2025.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/edgardjossa/Library/Python/3.9/lib/python/site-packages (from pandas->mofapy2) (2025.2)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=3.1.0->mofax) (1.15.0)
# Collecting threadpoolctl>=3.1.0
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Requirement already satisfied: joblib>=1.2.0 in /Users/edgardjossa/Library/Python/3.9/lib/python/site-packages (from scikit-learn<2,>=1->mofapy2) (1.5.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in /Users/edgardjossa/Library/Python/3.9/lib/python/site-packages (from exceptiongroup->anndata>0.8->mofapy2) (4.14.0)
# Installing collected packages: pyparsing, pillow, kiwisolver, importlib-resources, fonttools, cycler, contourpy, threadpoolctl, scipy, natsort, matplotlib, h5py, array-api-compat, seaborn, scikit-learn, anndata, mofax, mofapy2
# Successfully installed anndata-0.10.9 array-api-compat-1.11.2 contourpy-1.3.0 cycler-0.12.1 fonttools-4.60.1 h5py-3.14.0 importlib-resources-6.5.2 kiwisolver-1.4.7 matplotlib-3.9.4 mofapy2-0.7.2 mofax-0.3.7 natsort-8.4.0 pillow-11.3.0 pyparsing-3.2.5 scikit-learn-1.6.1 scipy-1.13.1 seaborn-0.13.2 threadpoolctl-3.6.0
# WARNING: You are using pip version 21.2.4; however, version 25.3 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# preparazione dati per mofa

# %%
import numpy as np

# Intersezione dei geni presenti in tutte le matrici
common_genes = (
    set(bp_filtered.index)
    & set(cc_filtered.index)
    & set(mf_filtered.index)
    & set(hpo.index)
)

common_genes = sorted(common_genes)

print(f"Geni in comune tra tutte le viste: {len(common_genes)}")

# Sottoselezioniamo e riordiniamo le matrici
bp_mofa  = bp_filtered.loc[common_genes]
cc_mofa  = cc_filtered.loc[common_genes]
mf_mofa  = mf_filtered.loc[common_genes]
hpo_mofa = hpo.loc[common_genes]
# Out:
# Geni in comune tra tutte le viste: 5183

# %% [markdown]
# Impostazione MOFA

# %%
from mofapy2.run.entry_point import entry_point
import pandas as pd

# ============================
# 1. Nomi di views, samples, features
# ============================

view_names = ["BP", "CC", "MF", "HPO"]
groups_names = ["genes"]   # abbiamo una sola group
sample_names = bp_mofa.index.tolist()  # stessi per tutte le viste

features_names = [
    bp_mofa.columns.tolist(),
    cc_mofa.columns.tolist(),
    mf_mofa.columns.tolist(),
    hpo_mofa.columns.tolist()
]

# ============================
# 2. Costruzione della lista "data"
#    struttura: data[view][group] = matrix (samples x features)
# ============================

data = [
    [bp_mofa.values],   # view BP, group "genes"
    [cc_mofa.values],   # view CC
    [mf_mofa.values],   # view MF
    [hpo_mofa.values]   # view HPO
]

likelihoods = ["bernoulli", "bernoulli", "bernoulli", "bernoulli"]

# ============================
# 3. Inizializza entry_point e setta i dati
# ============================

ent = entry_point()

# (opzionale) data options generali
ent.set_data_options(
    scale_views = False,
    scale_groups = False
)

# Qui il passaggio chiave: usare set_data_matrix
ent.set_data_matrix(
    data = data,
    likelihoods = likelihoods,
    views_names = view_names,
    groups_names = groups_names,
    samples_names = [sample_names],   # lista per group
    features_names = features_names   # lista per view
)
# Out:
#         #########################################################
#         ###           __  __  ____  ______                    ###
#         ###          |  \/  |/ __ \|  ____/\    _             ###
#         ###          | \  / | |  | | |__ /  \ _| |_           ###
#         ###          | |\/| | |  | |  __/ /\ \_   _|          ###
#         ###          | |  | | |__| | | / ____ \|_|            ###
#         ###          |_|  |_|\____/|_|/_/    \_\              ###
#         ###                                                   ###
#         #########################################################
#
#
#
# Successfully loaded view='BP' group='genes' with N=5183 samples and D=9439 features...
# Successfully loaded view='CC' group='genes' with N=5183 samples and D=1193 features...
# Successfully loaded view='MF' group='genes' with N=5183 samples and D=3042 features...
# Successfully loaded view='HPO' group='genes' with N=5183 samples and D=10185 features...

# %% [markdown]
# Impostazione modello e training

# %%
# ============================
# MODEL OPTIONS
# ============================

# Tutte le viste sono binarie → bernoulli
likelihoods = ["bernoulli"] * len(view_names)

ent.set_model_options(
    factors = 15,          # puoi portarlo a 15 se vuoi più fattori
    #likelihoods = likelihoods
)

# ============================
# TRAIN OPTIONS
# ============================

ent.set_train_options(
    iter = 500,           # se converge bene puoi aumentare
    convergence_mode = "fast",
    verbose = False,
    seed = 42              # per riproducibilità
)

# ============================
# BUILD + RUN
# ============================

ent.build()
ent.run()
# Out:
# Model options:
# - Automatic Relevance Determination prior on the factors: False
# - Automatic Relevance Determination prior on the weights: True
# - Spike-and-slab prior on the factors: False
# - Spike-and-slab prior on the weights: True
# Likelihoods:
# - View 0 (BP): bernoulli
# - View 1 (CC): bernoulli
# - View 2 (MF): bernoulli
# - View 3 (HPO): bernoulli
#
#
#
#
# ######################################
# ## Training the model with seed 42 ##
# ######################################
#
#
# ELBO before training: -258454611.48
#
# Iteration 1: time=16.21, ELBO=-133646524.67, deltaELBO=124808086.816 (48.29013733%), Factors=15
# Iteration 2: time=15.10, ELBO=-85545127.53, deltaELBO=48101397.142 (18.61115840%), Factors=15
# Iteration 3: time=14.36, ELBO=-85432746.38, deltaELBO=112381.142 (0.04348196%), Factors=15
# Iteration 4: time=14.27, ELBO=-85414599.98, deltaELBO=18146.408 (0.00702112%), Factors=15
# Iteration 5: time=13.98, ELBO=-85401001.37, deltaELBO=13598.609 (0.00526151%), Factors=15
# Iteration 6: time=14.02, ELBO=-85383132.92, deltaELBO=17868.447 (0.00691357%), Factors=15
# Iteration 7: time=14.09, ELBO=-85365227.44, deltaELBO=17905.484 (0.00692790%), Factors=15
# Iteration 8: time=14.32, ELBO=-85349482.76, deltaELBO=15744.675 (0.00609185%), Factors=15
# Iteration 9: time=15.11, ELBO=-85335757.45, deltaELBO=13725.314 (0.00531053%), Factors=15
# Iteration 10: time=14.29, ELBO=-85323416.76, deltaELBO=12340.690 (0.00477480%), Factors=15
# Iteration 11: time=14.25, ELBO=-85312049.06, deltaELBO=11367.695 (0.00439833%), Factors=15
# Iteration 12: time=14.14, ELBO=-85301480.27, deltaELBO=10568.795 (0.00408923%), Factors=15
# Iteration 13: time=14.86, ELBO=-85291629.75, deltaELBO=9850.517 (0.00381131%), Factors=15
# Iteration 14: time=14.28, ELBO=-85282421.79, deltaELBO=9207.962 (0.00356270%), Factors=15
# Iteration 15: time=14.00, ELBO=-85273785.37, deltaELBO=8636.419 (0.00334156%), Factors=15
# Iteration 16: time=14.63, ELBO=-85265650.34, deltaELBO=8135.033 (0.00314757%), Factors=15
# Iteration 17: time=15.18, ELBO=-85257948.39, deltaELBO=7701.947 (0.00298000%), Factors=15
# Iteration 18: time=14.45, ELBO=-85250631.17, deltaELBO=7317.215 (0.00283114%), Factors=15
# Iteration 19: time=13.90, ELBO=-85243671.05, deltaELBO=6960.125 (0.00269298%), Factors=15
# Iteration 20: time=14.43, ELBO=-85237026.78, deltaELBO=6644.269 (0.00257077%), Factors=15
# Iteration 21: time=14.04, ELBO=-85230648.44, deltaELBO=6378.341 (0.00246788%), Factors=15
# Iteration 22: time=14.34, ELBO=-85224510.12, deltaELBO=6138.319 (0.00237501%), Factors=15
# Iteration 23: time=13.84, ELBO=-85218604.67, deltaELBO=5905.452 (0.00228491%), Factors=15
# Iteration 24: time=14.45, ELBO=-85212903.49, deltaELBO=5701.179 (0.00220587%), Factors=15
# Iteration 25: time=13.95, ELBO=-85207398.16, deltaELBO=5505.330 (0.00213010%), Factors=15
# Iteration 26: time=13.46, ELBO=-85202077.56, deltaELBO=5320.598 (0.00205862%), Factors=15
# Iteration 27: time=13.78, ELBO=-85196922.82, deltaELBO=5154.745 (0.00199445%), Factors=15
# Iteration 28: time=13.45, ELBO=-85191917.23, deltaELBO=5005.585 (0.00193674%), Factors=15
# Iteration 29: time=13.90, ELBO=-85187047.29, deltaELBO=4869.944 (0.00188426%), Factors=15
# Iteration 30: time=13.52, ELBO=-85182265.85, deltaELBO=4781.436 (0.00185001%), Factors=15
# Iteration 31: time=14.39, ELBO=-85177584.63, deltaELBO=4681.216 (0.00181123%), Factors=15
# Iteration 32: time=14.39, ELBO=-85173012.06, deltaELBO=4572.577 (0.00176920%), Factors=15
# Iteration 33: time=14.26, ELBO=-85168533.39, deltaELBO=4478.663 (0.00173286%), Factors=15
# Iteration 34: time=13.83, ELBO=-85164141.49, deltaELBO=4391.907 (0.00169930%), Factors=15
# Iteration 35: time=14.16, ELBO=-85159828.81, deltaELBO=4312.681 (0.00166864%), Factors=15
# Iteration 36: time=14.61, ELBO=-85155580.68, deltaELBO=4248.127 (0.00164366%), Factors=15
# Iteration 37: time=14.97, ELBO=-85151388.78, deltaELBO=4191.904 (0.00162191%), Factors=15
# Iteration 38: time=14.93, ELBO=-85147239.59, deltaELBO=4149.189 (0.00160538%), Factors=15
# Iteration 39: time=14.77, ELBO=-85143086.49, deltaELBO=4153.098 (0.00160690%), Factors=15
# Iteration 40: time=13.73, ELBO=-85138893.24, deltaELBO=4193.246 (0.00162243%), Factors=15
# Iteration 41: time=13.92, ELBO=-85134656.33, deltaELBO=4236.910 (0.00163932%), Factors=15
# Iteration 42: time=13.81, ELBO=-85130385.38, deltaELBO=4270.953 (0.00165250%), Factors=15
# Iteration 43: time=13.89, ELBO=-85126049.39, deltaELBO=4335.990 (0.00167766%), Factors=15
# Iteration 44: time=13.94, ELBO=-85121643.70, deltaELBO=4405.692 (0.00170463%), Factors=15
# Iteration 45: time=13.93, ELBO=-85117169.74, deltaELBO=4473.957 (0.00173104%), Factors=15
# Iteration 46: time=13.82, ELBO=-85112641.45, deltaELBO=4528.288 (0.00175206%), Factors=15
# Iteration 47: time=13.85, ELBO=-85108085.65, deltaELBO=4555.807 (0.00176271%), Factors=15
# Iteration 48: time=14.30, ELBO=-85103489.55, deltaELBO=4596.096 (0.00177830%), Factors=15
# Iteration 49: time=13.79, ELBO=-85098880.79, deltaELBO=4608.759 (0.00178320%), Factors=15
# Iteration 50: time=13.50, ELBO=-84894105.37, deltaELBO=204775.425 (0.07923071%), Factors=15
# Iteration 51: time=13.84, ELBO=-84830964.52, deltaELBO=63140.851 (0.02443015%), Factors=15
# Iteration 52: time=14.14, ELBO=-84811859.44, deltaELBO=19105.075 (0.00739204%), Factors=15
# Iteration 53: time=14.12, ELBO=-84802522.78, deltaELBO=9336.664 (0.00361250%), Factors=15
# Iteration 54: time=14.89, ELBO=-84796643.46, deltaELBO=5879.317 (0.00227480%), Factors=15
# Iteration 55: time=14.02, ELBO=-84792201.21, deltaELBO=4442.247 (0.00171877%), Factors=15
# Iteration 56: time=13.61, ELBO=-84788383.30, deltaELBO=3817.915 (0.00147721%), Factors=15
# Iteration 57: time=13.85, ELBO=-84784854.71, deltaELBO=3528.588 (0.00136526%), Factors=15
# Iteration 58: time=13.42, ELBO=-84781504.33, deltaELBO=3350.382 (0.00129631%), Factors=15
# Iteration 59: time=13.99, ELBO=-84778273.73, deltaELBO=3230.602 (0.00124997%), Factors=15
# Iteration 60: time=13.60, ELBO=-84775201.71, deltaELBO=3072.018 (0.00118861%), Factors=15
# Iteration 61: time=14.43, ELBO=-84772179.61, deltaELBO=3022.098 (0.00116930%), Factors=15
# Iteration 62: time=13.96, ELBO=-84769236.46, deltaELBO=2943.149 (0.00113875%), Factors=15
# Iteration 63: time=13.56, ELBO=-84766368.81, deltaELBO=2867.654 (0.00110954%), Factors=15
# Iteration 64: time=13.78, ELBO=-84763560.58, deltaELBO=2808.224 (0.00108654%), Factors=15
# Iteration 65: time=13.67, ELBO=-84760807.11, deltaELBO=2753.474 (0.00106536%), Factors=15
# Iteration 66: time=13.80, ELBO=-84758081.24, deltaELBO=2725.868 (0.00105468%), Factors=15
# Iteration 67: time=13.57, ELBO=-84755390.09, deltaELBO=2691.155 (0.00104125%), Factors=15
# Iteration 68: time=13.95, ELBO=-84752763.85, deltaELBO=2626.232 (0.00101613%), Factors=15
# Iteration 69: time=13.84, ELBO=-84750196.29, deltaELBO=2567.563 (0.00099343%), Factors=15
# Iteration 70: time=13.65, ELBO=-84747633.46, deltaELBO=2562.833 (0.00099160%), Factors=15
# Iteration 71: time=13.77, ELBO=-84745056.38, deltaELBO=2577.076 (0.00099711%), Factors=15
# Iteration 72: time=13.68, ELBO=-84742479.90, deltaELBO=2576.480 (0.00099688%), Factors=15
# Iteration 73: time=13.58, ELBO=-84739955.29, deltaELBO=2524.608 (0.00097681%), Factors=15
# Iteration 74: time=13.18, ELBO=-84737468.30, deltaELBO=2486.996 (0.00096226%), Factors=15
# Iteration 75: time=13.46, ELBO=-84735036.58, deltaELBO=2431.720 (0.00094087%), Factors=15
# Iteration 76: time=13.67, ELBO=-84732647.75, deltaELBO=2388.824 (0.00092427%), Factors=15
# Iteration 77: time=13.62, ELBO=-84730303.11, deltaELBO=2344.646 (0.00090718%), Factors=15
# Iteration 78: time=13.37, ELBO=-84727952.13, deltaELBO=2350.984 (0.00090963%), Factors=15
# Iteration 79: time=13.51, ELBO=-84725632.99, deltaELBO=2319.135 (0.00089731%), Factors=15
# Iteration 80: time=14.83, ELBO=-84723335.37, deltaELBO=2297.622 (0.00088898%), Factors=15
# Iteration 81: time=14.08, ELBO=-84721072.22, deltaELBO=2263.148 (0.00087565%), Factors=15
# Iteration 82: time=13.67, ELBO=-84718857.93, deltaELBO=2214.290 (0.00085674%), Factors=15
# Iteration 83: time=13.44, ELBO=-84716646.56, deltaELBO=2211.374 (0.00085561%), Factors=15
# Iteration 84: time=14.07, ELBO=-84714442.53, deltaELBO=2204.027 (0.00085277%), Factors=15
# Iteration 85: time=13.81, ELBO=-84712278.43, deltaELBO=2164.101 (0.00083732%), Factors=15
# Iteration 86: time=14.01, ELBO=-84710164.08, deltaELBO=2114.349 (0.00081807%), Factors=15
# Iteration 87: time=13.84, ELBO=-84708057.84, deltaELBO=2106.239 (0.00081494%), Factors=15
# Iteration 88: time=13.68, ELBO=-84705954.74, deltaELBO=2103.103 (0.00081372%), Factors=15
# Iteration 89: time=13.81, ELBO=-84703871.65, deltaELBO=2083.086 (0.00080598%), Factors=15
# Iteration 90: time=13.96, ELBO=-84701806.07, deltaELBO=2065.580 (0.00079920%), Factors=15
# Iteration 91: time=13.38, ELBO=-84699740.16, deltaELBO=2065.910 (0.00079933%), Factors=15
# Iteration 92: time=13.42, ELBO=-84697681.31, deltaELBO=2058.854 (0.00079660%), Factors=15
# Iteration 93: time=14.71, ELBO=-84695624.26, deltaELBO=2057.047 (0.00079590%), Factors=15
# Iteration 94: time=14.43, ELBO=-84693615.93, deltaELBO=2008.333 (0.00077705%), Factors=15
# Iteration 95: time=13.91, ELBO=-84691635.42, deltaELBO=1980.505 (0.00076629%), Factors=15
# Iteration 96: time=13.95, ELBO=-84689661.12, deltaELBO=1974.297 (0.00076389%), Factors=15
# Iteration 97: time=13.42, ELBO=-84687686.63, deltaELBO=1974.491 (0.00076396%), Factors=15
# Iteration 98: time=13.61, ELBO=-84685738.53, deltaELBO=1948.103 (0.00075375%), Factors=15
# Iteration 99: time=13.63, ELBO=-84683794.36, deltaELBO=1944.168 (0.00075223%), Factors=15
# Iteration 100: time=13.75, ELBO=-84681857.92, deltaELBO=1936.442 (0.00074924%), Factors=15
# Iteration 101: time=13.44, ELBO=-84679932.74, deltaELBO=1925.183 (0.00074488%), Factors=15
# Iteration 102: time=13.38, ELBO=-84678034.98, deltaELBO=1897.760 (0.00073427%), Factors=15
# Iteration 103: time=13.62, ELBO=-84676190.05, deltaELBO=1844.926 (0.00071383%), Factors=15
# Iteration 104: time=13.92, ELBO=-84674360.72, deltaELBO=1829.328 (0.00070779%), Factors=15
# Iteration 105: time=13.97, ELBO=-84672544.51, deltaELBO=1816.218 (0.00070272%), Factors=15
# Iteration 106: time=14.13, ELBO=-84670710.09, deltaELBO=1834.414 (0.00070976%), Factors=15
# Iteration 107: time=16.63, ELBO=-84668901.95, deltaELBO=1808.139 (0.00069960%), Factors=15
# Iteration 108: time=14.61, ELBO=-84667100.90, deltaELBO=1801.049 (0.00069685%), Factors=15
# Iteration 109: time=13.79, ELBO=-84665317.62, deltaELBO=1783.281 (0.00068998%), Factors=15
# Iteration 110: time=13.30, ELBO=-84663552.39, deltaELBO=1765.231 (0.00068299%), Factors=15
# Iteration 111: time=13.76, ELBO=-84661800.09, deltaELBO=1752.297 (0.00067799%), Factors=15
# Iteration 112: time=13.67, ELBO=-84660068.56, deltaELBO=1731.536 (0.00066996%), Factors=15
# Iteration 113: time=13.53, ELBO=-84658347.83, deltaELBO=1720.734 (0.00066578%), Factors=15
# Iteration 114: time=13.58, ELBO=-84656639.56, deltaELBO=1708.265 (0.00066095%), Factors=15
# Iteration 115: time=13.55, ELBO=-84654938.64, deltaELBO=1700.919 (0.00065811%), Factors=15
# Iteration 116: time=13.43, ELBO=-84653246.04, deltaELBO=1692.597 (0.00065489%), Factors=15
# Iteration 117: time=13.29, ELBO=-84651551.09, deltaELBO=1694.958 (0.00065580%), Factors=15
# Iteration 118: time=13.62, ELBO=-84649862.17, deltaELBO=1688.917 (0.00065347%), Factors=15
# Iteration 119: time=13.41, ELBO=-84648183.76, deltaELBO=1678.405 (0.00064940%), Factors=15
# Iteration 120: time=13.60, ELBO=-84646508.81, deltaELBO=1674.953 (0.00064806%), Factors=15
# Iteration 121: time=13.76, ELBO=-84644856.93, deltaELBO=1651.878 (0.00063914%), Factors=15
# Iteration 122: time=13.78, ELBO=-84643219.40, deltaELBO=1637.536 (0.00063359%), Factors=15
# Iteration 123: time=13.83, ELBO=-84641586.40, deltaELBO=1632.993 (0.00063183%), Factors=15
# Iteration 124: time=13.70, ELBO=-84639961.88, deltaELBO=1624.522 (0.00062855%), Factors=15
# Iteration 125: time=13.67, ELBO=-84638345.73, deltaELBO=1616.148 (0.00062531%), Factors=15
# Iteration 126: time=13.35, ELBO=-84636742.43, deltaELBO=1603.301 (0.00062034%), Factors=15
# Iteration 127: time=14.44, ELBO=-84635158.77, deltaELBO=1583.665 (0.00061274%), Factors=15
# Iteration 128: time=14.13, ELBO=-84633576.05, deltaELBO=1582.714 (0.00061238%), Factors=15
# Iteration 129: time=13.92, ELBO=-84631995.64, deltaELBO=1580.415 (0.00061149%), Factors=15
# Iteration 130: time=13.86, ELBO=-84630400.04, deltaELBO=1595.599 (0.00061736%), Factors=15
# Iteration 131: time=13.97, ELBO=-84628802.82, deltaELBO=1597.217 (0.00061799%), Factors=15
# Iteration 132: time=13.93, ELBO=-84627225.83, deltaELBO=1576.998 (0.00061016%), Factors=15
# Iteration 133: time=14.03, ELBO=-84625674.76, deltaELBO=1551.064 (0.00060013%), Factors=15
# Iteration 134: time=14.48, ELBO=-84624134.74, deltaELBO=1540.022 (0.00059586%), Factors=15
# Iteration 135: time=14.07, ELBO=-84622595.14, deltaELBO=1539.602 (0.00059570%), Factors=15
# Iteration 136: time=13.70, ELBO=-84621066.51, deltaELBO=1528.624 (0.00059145%), Factors=15
# Iteration 137: time=13.94, ELBO=-84619557.51, deltaELBO=1509.002 (0.00058386%), Factors=15
# Iteration 138: time=13.85, ELBO=-84618059.69, deltaELBO=1497.820 (0.00057953%), Factors=15
# Iteration 139: time=13.69, ELBO=-84616581.78, deltaELBO=1477.915 (0.00057183%), Factors=15
# Iteration 140: time=13.65, ELBO=-84615116.13, deltaELBO=1465.641 (0.00056708%), Factors=15
# Iteration 141: time=14.38, ELBO=-84613665.89, deltaELBO=1450.244 (0.00056112%), Factors=15
# Iteration 142: time=13.76, ELBO=-84612215.01, deltaELBO=1450.884 (0.00056137%), Factors=15
# Iteration 143: time=14.21, ELBO=-84610773.00, deltaELBO=1442.011 (0.00055794%), Factors=15
# Iteration 144: time=13.98, ELBO=-84609349.99, deltaELBO=1423.007 (0.00055058%), Factors=15
# Iteration 145: time=13.41, ELBO=-84607947.46, deltaELBO=1402.526 (0.00054266%), Factors=15
# Iteration 146: time=13.71, ELBO=-84606554.05, deltaELBO=1393.414 (0.00053913%), Factors=15
# Iteration 147: time=13.41, ELBO=-84605166.81, deltaELBO=1387.239 (0.00053674%), Factors=15
# Iteration 148: time=13.75, ELBO=-84603791.47, deltaELBO=1375.344 (0.00053214%), Factors=15
# Iteration 149: time=14.39, ELBO=-84602428.92, deltaELBO=1362.545 (0.00052719%), Factors=15
# Iteration 150: time=13.83, ELBO=-84601077.91, deltaELBO=1351.009 (0.00052273%), Factors=15
# Iteration 151: time=14.09, ELBO=-84599737.16, deltaELBO=1340.754 (0.00051876%), Factors=15
# Iteration 152: time=13.63, ELBO=-84598405.40, deltaELBO=1331.754 (0.00051528%), Factors=15
# Iteration 153: time=13.83, ELBO=-84597082.14, deltaELBO=1323.261 (0.00051199%), Factors=15
# Iteration 154: time=14.41, ELBO=-84595761.56, deltaELBO=1320.578 (0.00051095%), Factors=15
# Iteration 155: time=13.39, ELBO=-84594437.08, deltaELBO=1324.484 (0.00051246%), Factors=15
# Iteration 156: time=13.38, ELBO=-84593102.91, deltaELBO=1334.172 (0.00051621%), Factors=15
# Iteration 157: time=13.64, ELBO=-84591770.14, deltaELBO=1332.768 (0.00051567%), Factors=15
# Iteration 158: time=13.73, ELBO=-84590473.13, deltaELBO=1297.011 (0.00050183%), Factors=15
# Iteration 159: time=13.70, ELBO=-84589181.19, deltaELBO=1291.943 (0.00049987%), Factors=15
# Iteration 160: time=14.57, ELBO=-84587894.29, deltaELBO=1286.901 (0.00049792%), Factors=15
#
# Converged!
#
#
#
# #######################
# ## Training finished ##
# #######################

# %% [markdown]
# Normalizzazione dei fattori

# %% [markdown]
# recupero modello e Z_df

# %%
model = ent.model
# 1) Recupera la matrice dei fattori (samples × factors)
Z = model.nodes["Z"].getExpectation()   # shape: n_samples x n_factors

# 2) Costruiamo i nomi dei fattori
n_factors = Z.shape[1]
factor_names = [f"Factor_{i+1}" for i in range(n_factors)]

# 3) sample_names è la lista dei geni che hai usato quando hai chiamato set_data_matrix
Z_df = pd.DataFrame(Z, index=sample_names, columns=factor_names)

Z_df.head()
# Out:
#     Factor_1  Factor_2  Factor_3  Factor_4  Factor_5  Factor_6  Factor_7  \
# 10 -1.528164 -0.219360 -0.484415 -0.629754 -0.789675 -0.245350 -0.070914
# 16  1.797280  1.568492  1.285880  2.524589  0.016328  0.287927  0.019602
# 18 -0.093573  0.643556 -0.519884  1.134285  0.142406 -0.591759 -0.086393
# 19 -0.630183  0.260709  1.130637  0.406203  0.954438  0.043279 -0.103697
# 20 -0.224720  0.489900 -0.718707  0.549555  0.655517 -0.209147 -0.110507
#
#     Factor_8  Factor_9  Factor_10  Factor_11  Factor_12  Factor_13  Factor_14  \
# 10  0.438244 -0.136542  -0.441986   0.265167   0.258670  -0.582551   0.165055
# 16  0.115844 -0.513638   0.519985  -4.455684   0.119780   1.431877  -0.106695
# 18  0.265990 -0.361446  -0.384800   0.111004   0.329112  -0.195219  -0.160302
# 19  1.167427 -0.030682   1.093844   0.274660   0.913916   0.775418   1.342394
# 20  0.681516 -0.426076  -0.520482  -0.189728   0.387645   0.509050   0.479071
#
#     Factor_15
# 10  -0.226908
# 16  -0.662328
# 18  -0.669971
# 19  -0.320074
# 20  -0.013067

# %%
Z_df.shape
# Out:
# (5183, 15)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
Z_scaled = scaler.fit_transform(Z_df.values)  # stessa forma di Z_df ma scalata

print(Z_scaled)
# Out:
# [[-1.16774155 -0.19517905 -0.50065367 ... -0.61839184  0.16328802
#   -0.22503333]
#  [ 1.34909994  1.29299421  1.30222208 ...  1.47023654 -0.12004815
#   -0.66077824]
#  [-0.08198019  0.52309551 -0.53677627 ... -0.21679277 -0.17594085
#   -0.66842647]
#  ...
#  [-1.20742413 -0.29551312 -0.13019709 ... -0.03832999  0.27672688
#   -0.29521773]
#  [-0.97738517 -0.06352661 -0.59825479 ... -0.58426072  0.05809084
#   -0.22346255]
#  [-0.66068333  0.09551916  0.04088816 ... -1.09680149 -0.1399512
#   -0.46700683]]

# %% [markdown]
# matrice di similarità integrata

# %%
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd

# Usa Z_scaled se hai fatto lo scaling, altrimenti Z_df.values
similarity_matrix = cosine_similarity(Z_scaled)

# Trasformiamo in DataFrame con indici/colonne = geni
similarity_df = pd.DataFrame(
    similarity_matrix,
    index=Z_df.index,
    columns=Z_df.index
)

similarity_df.iloc[:5, :5]
# Out:
#           10        16        18        19        20
# 10  1.000000 -0.537270  0.067727 -0.181525  0.015518
# 16 -0.537270  1.000000  0.218143  0.163049  0.223054
# 18  0.067727  0.218143  1.000000  0.015544  0.604291
# 19 -0.181525  0.163049  0.015544  1.000000  0.332780
# 20  0.015518  0.223054  0.604291  0.332780  1.000000

# %% [markdown]
# Visualizzazione similarità

# %%
import seaborn as sns
sns.heatmap(similarity_df.iloc[:20, :20])
# Out:
# <Axes: >

# %% [markdown]
# CLUSTERING

# %%
from sklearn.cluster import SpectralClustering

# Z_scaled: matrice (n_geni × n_fattori) che hai usato per la cosine
sc = SpectralClustering(
    n_clusters=3,
    affinity='nearest_neighbors',
    n_neighbors=10,
    random_state=42
)

labels = sc.fit_predict(Z_scaled)
Z_df["cluster"] = labels
Z_df

#np.unique(labels, return_counts=True)
# Out:
#            Factor_1  Factor_2  Factor_3  Factor_4  Factor_5  Factor_6  \
# 10        -1.528164 -0.219360 -0.484415 -0.629754 -0.789675 -0.245350
# 16         1.797280  1.568492  1.285880  2.524589  0.016328  0.287927
# 18        -0.093573  0.643556 -0.519884  1.134285  0.142406 -0.591759
# 19        -0.630183  0.260709  1.130637  0.406203  0.954438  0.043279
# 20        -0.224720  0.489900 -0.718707  0.549555  0.655517 -0.209147
# ...             ...       ...       ...       ...       ...       ...
# 105371045 -0.445358  0.399338  0.865613 -0.411385 -0.476186  0.217040
# 105804841 -0.711215  0.059987 -0.921559 -1.503491 -0.796506 -0.393623
# 109580095 -1.580596 -0.339899 -0.120653 -0.623555 -0.797629 -0.249815
# 111365204 -1.276651 -0.061197 -0.580252 -0.823566 -0.835968  0.828288
# 120766137 -0.858200  0.129877  0.047341 -1.486571 -0.586063 -0.301691
#
#            Factor_7  Factor_8  Factor_9  Factor_10  Factor_11  Factor_12  \
# 10        -0.070914  0.438244 -0.136542  -0.441986   0.265167   0.258670
# 16         0.019602  0.115844 -0.513638   0.519985  -4.455684   0.119780
# 18        -0.086393  0.265990 -0.361446  -0.384800   0.111004   0.329112
# 19        -0.103697  1.167427 -0.030682   1.093844   0.274660   0.913916
# 20        -0.110507  0.681516 -0.426076  -0.520482  -0.189728   0.387645
# ...             ...       ...       ...        ...        ...        ...
# 105371045 -0.097974  0.366010 -0.317372  -0.177008   0.394441   0.182332
# 105804841 -0.135441  0.512142 -0.178670  -0.152628   0.164787   0.017818
# 109580095 -0.067868  0.481016 -0.205920  -0.647687   0.108054   0.404596
# 111365204 -0.072778  0.435680 -0.275706  -0.427081  -0.076217   0.236644
# 120766137 -0.080910  0.047591 -0.378094  -0.613189   0.143882   0.611635
#
#            Factor_13  Factor_14  Factor_15  cluster
# 10         -0.582551   0.165055  -0.226908        0
# 16          1.431877  -0.106695  -0.662328        0
# 18         -0.195219  -0.160302  -0.669971        0
# 19          0.775418   1.342394  -0.320074        0
# 20          0.509050   0.479071  -0.013067        0
# ...              ...        ...        ...      ...
# 105371045  -0.613813  -0.144486  -0.292844        0
# 105804841   0.155049   0.295285   1.073992        0
# 109580095  -0.023097   0.273855  -0.297040        0
# 111365204  -0.549633   0.064159  -0.225338        0
# 120766137  -1.043965  -0.125784  -0.468701        0
#
# [5183 rows x 16 columns]

# %% [markdown]
# Numero di cluster ottimale

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import numpy as np

Ks = range(2, 11)   # proviamo k da 2 a 10
sil_scores = []

for k in Ks:
    km = KMeans(n_clusters=k, random_state=42, n_init=10)
    labels_k = km.fit_predict(Z_scaled)
    score = silhouette_score(Z_scaled, labels_k)
    sil_scores.append(score)
    print(f"k={k}, silhouette={score:.4f}")

best_k = Ks[int(np.argmax(sil_scores))]
print("k scelto (massimo silhouette):", best_k)
# Out:
# k=2, silhouette=0.3331
# k=3, silhouette=0.3357
# k=4, silhouette=0.1388
# k=5, silhouette=0.1357
# k=6, silhouette=0.1400
# k=7, silhouette=0.1653
# k=8, silhouette=0.1792
# k=9, silhouette=0.1695
# k=10, silhouette=0.1903
# k scelto (massimo silhouette): 3

# %% [markdown]
# Spectral with optimal k

# %% [markdown]
# Pulisco la Z_df

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics.pairwise import cosine_similarity

# 1) Partiamo da Z_df originale (senza cluster dentro)
Z_clean = Z_df.copy()

# Se hai già aggiunto la colonna 'cluster', rimuovila per sicurezza:
if "cluster" in Z_clean.columns:
    Z_clean = Z_clean.drop(columns=["cluster"])

# 2) Rimuovi i fattori con varianza zero (colonne costanti)
var_factors = Z_clean.var()
Z_clean = Z_clean.loc[:, var_factors > 0]

print("Fattori usati:", Z_clean.shape[1])

# 3) Rimuovi eventuali geni (righe) che hanno NaN nei fattori
Z_clean = Z_clean.dropna(axis=0)
print("Geni rimasti dopo dropna:", Z_clean.shape[0])

# 4) Standardizzazione
scaler = StandardScaler()
Z_scaled = scaler.fit_transform(Z_clean.values)

# 5) Ricostruzione della similarity (cosine)
similarity_matrix = cosine_similarity(Z_scaled)

sim = pd.DataFrame(
    similarity_matrix,
    index=Z_clean.index,
    columns=Z_clean.index
)

# 6) Controllo finale sui NaN
print("NaN nella similarity:", sim.isna().sum().sum())
# Out:
# Fattori usati: 15
# Geni rimasti dopo dropna: 5183
# NaN nella similarity: 0

# %%
import numpy as np

print("NaN totali in sim:", sim.isna().sum().sum())

# Vedi quali geni hanno almeno un NaN nella riga/colonna
mask_nan_rows = sim.isna().any(axis=1)   # True = riga con almeno un NaN
genes_with_nan = sim.index[mask_nan_rows]

print("Numero di geni con almeno un NaN:", mask_nan_rows.sum())
print("Primi geni con NaN:", genes_with_nan[:10].tolist())
# Out:
# NaN totali in sim: 0
# Numero di geni con almeno un NaN: 0
# Primi geni con NaN: []

# %%
from sklearn.cluster import SpectralClustering

sc = SpectralClustering(
    n_clusters=best_k,
    affinity='nearest_neighbors',  # costruisce lui la matrice di affinità
    n_neighbors=10,                # puoi variare (5–20)
    random_state=42
)

labels = sc.fit_predict(Z_scaled)

Z_clean["cluster"] = labels

# Distribuzione dei geni per cluster
unique, counts = np.unique(labels, return_counts=True)
for c, n in zip(unique, counts):
    print(f"Cluster {c}: {n} geni")
# Out:
# Cluster 0: 5136 geni
# Cluster 1: 29 geni
# Cluster 2: 18 geni

# %%
# Restrizione a geni usati in Z_clean
sim_for_plot = sim.loc[Z_clean.index, Z_clean.index]

# Ordine secondo i cluster
order = np.argsort(Z_clean["cluster"].values)
genes_ordered = sim_for_plot.index[order]

sim_ordered = sim_for_plot.loc[genes_ordered, genes_ordered]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(6,6))
sns.heatmap(sim_ordered, cmap="magma", vmin=0, vmax=1)
plt.title("Matrice di similarità integrata ordinata per cluster (Spectral su Z_scaled)")
plt.show()

# %%
pip install umap-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: umap-learn in /Users/edgardjossa/Library/Python/3.9/lib/python/site-packages (0.5.9.post2)
# Requirement already satisfied: scipy>=1.3.1 in /Users/edgardjossa/Library/Python/3.9/lib/python/site-packages (from umap-learn) (1.13.1)
# Requirement already satisfied: pynndescent>=0.5 in /Users/edgardjossa/Library/Python/3.9/lib/python/site-packages (from umap-learn) (0.5.13)
# Requirement already satisfied: scikit-learn>=1.6 in /Users/edgardjossa/Library/Python/3.9/lib/python/site-packages (from umap-learn) (1.6.1)
# Requirement already satisfied: numba>=0.51.2 in /Users/edgardjossa/Library/Python/3.9/lib/python/site-packages (from umap-learn) (0.60.0)
# Requirement already satisfied: tqdm in /Users/edgardjossa/Library/Python/3.9/lib/python/site-packages (from umap-learn) (4.67.1)
# Requirement already satisfied: numpy>=1.23 in /Users/edgardjossa/Library/Python/3.9/lib/python/site-packages (from umap-learn) (2.0.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /Users/edgardjossa/Library/Python/3.9/lib/python/site-packages (from numba>=0.51.2->umap-learn) (0.43.0)
# Requirement already satisfied: joblib>=0.11 in /Users/edgardjossa/Library/Python/3.9/lib/python/site-packages (from pynndescent>=0.5->umap-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/edgardjossa/Library/Python/3.9/lib/python/site-packages (from scikit-learn>=1.6->umap-learn) (3.6.0)
# WARNING: You are using pip version 21.2.4; however, version 25.3 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# UMAP

# %%
import umap
import numpy as np
import pandas as pd

# UMAP con parametri standard per dati continui
reducer = umap.UMAP(
    n_neighbors=15,         # quanto guardi “in locale”
    min_dist=0.1,           # quanto compatti i cluster
    metric='euclidean',
    random_state=42
)

umap_coords = reducer.fit_transform(Z_scaled)

# Costruiamo un DataFrame per comodo
UMAP_df = pd.DataFrame({
    "UMAP1": umap_coords[:,0],
    "UMAP2": umap_coords[:,1],
    "cluster": Z_clean["cluster"].values
}, index=Z_clean.index)

UMAP_df
# Out:
#                UMAP1     UMAP2  cluster
# 10          5.373604  6.273725        0
# 16         10.070495 -0.342112        0
# 18          7.729909  1.876693        0
# 19          4.529934  3.095731        0
# 20          7.971571  2.241178        0
# ...              ...       ...      ...
# 105371045   4.036974  3.645935        0
# 105804841   6.118507  4.489820        0
# 109580095   5.333728  6.122866        0
# 111365204   5.708459  7.392431        0
# 120766137   4.631822  4.763682        0
#
# [5183 rows x 3 columns]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.spatial import ConvexHull

plt.figure(figsize=(10, 8))

# palette cluster
palette = sns.color_palette("tab10", len(UMAP_df["cluster"].unique()))

# plot punti
sns.scatterplot(
    data=UMAP_df,
    x="UMAP1",
    y="UMAP2",
    hue="cluster",
    palette=palette,
    s=40,
    alpha=0.9
)

# Convex hull + centroidi
for c in UMAP_df["cluster"].unique():
    subset = UMAP_df[UMAP_df["cluster"] == c][["UMAP1", "UMAP2"]].values
    
    # calcolo centroide
    centroid = subset.mean(axis=0)
    
    # disegno del centroide
    plt.scatter(centroid[0], centroid[1], marker="X", s=200, c=[palette[c]], edgecolor="black")
    plt.text(centroid[0]+0.1, centroid[1], f"Cluster {c}", fontsize=12, weight="bold")
    
    # Convex hull (solo se > 3 punti)
    if subset.shape[0] > 3:
        hull = ConvexHull(subset)
        hull_points = subset[hull.vertices]
        plt.fill(
            hull_points[:,0],
            hull_points[:,1],
            alpha=0.15,
            color=palette[c]
        )

plt.title("UMAP dei geni integrati (con hull e centroidi)", fontsize=16)
plt.xlabel("UMAP1")
plt.ylabel("UMAP2")
plt.legend(title="Cluster")
plt.tight_layout()
plt.show()

# %% [markdown]
# Interpretazione dei cluster (GO & HPO enrichment)

# %% [markdown]
# estrazione geni per clusters

# %%
clusters = {}
for c in sorted(Z_clean["cluster"].unique()):
    clusters[c] = Z_clean.index[Z_clean["cluster"] == c].tolist()

clusters
# Out:
# {np.int32(0): [10,
#   16,
#   18,
#   19,
#   20,
#   21,
#   22,
#   24,
#   31,
#   34,
#   35,
#   36,
#   37,
#   38,
#   39,
#   49,
#   50,
#   51,
#   54,
#   58,
#   59,
#   60,
#   70,
#   71,
#   72,
#   81,
#   87,
#   88,
#   90,
#   91,
#   93,
#   94,
#   95,
#   100,
#   102,
#   103,
#   104,
#   107,
#   109,
#   111,
#   112,
#   118,
#   120,
#   125,
#   126,
#   128,
#   132,
#   135,
#   150,
#   151,
#   153,
#   155,
#   158,
#   162,
#   164,
#   174,
#   175,
#   176,
#   178,
#   181,
#   182,
#   183,
#   185,
#   189,
#   190,
#   191,
#   196,
#   197,
#   203,
#   204,
#   207,
#   208,
#   210,
#   212,
#   213,
#   215,
#   217,
#   220,
#   224,
#   226,
#   229,
#   238,
#   240,
#   241,
#   242,
#   249,
#   257,
#   258,
#   265,
#   267,
#   268,
#   269,
#   270,
#   271,
#   272,
#   274,
#   275,
#   283,
#   284,
#   285,
#   286,
#   287,
#   288,
#   291,
#   308,
#   311,
#   318,
#   324,
#   326,
#   330,
#   331,
#   335,
#   336,
#   338,
#   344,
#   345,
#   348,
#   351,
#   353,
#   355,
#   356,
#   359,
#   361,
#   362,
#   367,
#   368,
#   372,
#   375,
#   383,
#   387,
#   396,
#   399,
#   401,
#   402,
#   403,
#   407,
#   410,
#   411,
#   412,
#   415,
#   421,
#   427,
#   429,
#   435,
#   439,
#   440,
#   443,
#   445,
#   462,
#   463,
#   471,
#   472,
#   473,
#   474,
#   476,
#   477,
#   478,
#   481,
#   486,
#   487,
#   488,
#   490,
#   491,
#   492,
#   498,
#   501,
#   506,
#   513,
#   514,
#   518,
#   523,
#   525,
#   526,
#   527,
#   529,
#   535,
#   537,
#   538,
#   539,
#   540,
#   545,
#   546,
#   547,
#   549,
#   551,
#   554,
#   558,
#   567,
#   570,
#   579,
#   580,
#   581,
#   582,
#   583,
#   585,
#   587,
#   590,
#   593,
#   594,
#   595,
#   596,
#   604,
#   610,
#   611,
#   613,
#   617,
#   627,
#   629,
#   631,
#   640,
#   641,
#   644,
#   646,
#   649,
#   650,
#   652,
#   654,
#   657,
#   658,
#   659,
#   667,
#   668,
#   669,
#   672,
#   673,
#   675,
#   676,
#   678,
#   686,
#   695,
#   699,
#   701,
#   708,
#   710,
#   712,
#   713,
#   714,
#   715,
#   716,
#   717,
#   718,
#   720,
#   721,
#   726,
#   727,
#   729,
#   730,
#   731,
#   732,
#   735,
#   738,
#   745,
#   755,
#   760,
#   762,
#   763,
#   767,
#   771,
#   773,
#   774,
#   775,
#   776,
#   777,
#   778,
#   779,
#   781,
#   783,
#   785,
#   788,
#   790,
#   799,
#   801,
#   805,
#   808,
#   811,
#   815,
#   816,
#   818,
#   819,
#   823,
#   825,
#   826,
#   831,
#   833,
#   835,
#   841,
#   843,
#   844,
#   845,
#   846,
#   847,
#   857,
#   859,
#   860,
#   861,
#   865,
#   866,
#   867,
#   868,
#   871,
#   881,
#   889,
#   894,
#   899,
#   915,
#   916,
#   917,
#   919,
#   920,
#   925,
#   930,
#   931,
#   939,
#   940,
#   948,
#   950,
#   953,
#   958,
#   959,
#   966,
#   970,
#   973,
#   974,
#   975,
#   977,
#   987,
#   990,
#   991,
#   998,
#   999,
#   1000,
#   1001,
#   1009,
#   1013,
#   1019,
#   1020,
#   1021,
#   1024,
#   1026,
#   1027,
#   1028,
#   1029,
#   1030,
#   1031,
#   1041,
#   1050,
#   1053,
#   1056,
#   1062,
#   1063,
#   1066,
#   1071,
#   1073,
#   1075,
#   1080,
#   1084,
#   1103,
#   1105,
#   1106,
#   1107,
#   1108,
#   1109,
#   1111,
#   1116,
#   1119,
#   1120,
#   1121,
#   1123,
#   1130,
#   1131,
#   1134,
#   1135,
#   1136,
#   1137,
#   1139,
#   1140,
#   1141,
#   1144,
#   1145,
#   1146,
#   1147,
#   1161,
#   1173,
#   1174,
#   1175,
#   1180,
#   1181,
#   1182,
#   1183,
#   1184,
#   1185,
#   1186,
#   1187,
#   1188,
#   1193,
#   1200,
#   1201,
#   1203,
#   1213,
#   1230,
#   1235,
#   1244,
#   1258,
#   1259,
#   1261,
#   1267,
#   1272,
#   1277,
#   1278,
#   1280,
#   1282,
#   1284,
#   1285,
#   1286,
#   1287,
#   1288,
#   1289,
#   1290,
#   1291,
#   1292,
#   1293,
#   1294,
#   1296,
#   1297,
#   1298,
#   1299,
#   1300,
#   1301,
#   1302,
#   1303,
#   1305,
#   1308,
#   1311,
#   1312,
#   1314,
#   1315,
#   1316,
#   1317,
#   1326,
#   1327,
#   1337,
#   1339,
#   1340,
#   1349,
#   1351,
#   1352,
#   1353,
#   1355,
#   1356,
#   1357,
#   1363,
#   1369,
#   1371,
#   1373,
#   1374,
#   1376,
#   1380,
#   1384,
#   1385,
#   1387,
#   1392,
#   1399,
#   1406,
#   1407,
#   1409,
#   1410,
#   1411,
#   1412,
#   1413,
#   1414,
#   1415,
#   1417,
#   1419,
#   1420,
#   1421,
#   1427,
#   1428,
#   1436,
#   1438,
#   1439,
#   1441,
#   1453,
#   1457,
#   1460,
#   1462,
#   1468,
#   1471,
#   1474,
#   1475,
#   1476,
#   1478,
#   1482,
#   1487,
#   1490,
#   1491,
#   1493,
#   1495,
#   1496,
#   1497,
#   1499,
#   1500,
#   1501,
#   1503,
#   1508,
#   1509,
#   1512,
#   1513,
#   1523,
#   1528,
#   1534,
#   1535,
#   1536,
#   1537,
#   1538,
#   1540,
#   1545,
#   1548,
#   1559,
#   1565,
#   1576,
#   1577,
#   1581,
#   1583,
#   1584,
#   1585,
#   1586,
#   1588,
#   1589,
#   1591,
#   1593,
#   1594,
#   1600,
#   1604,
#   1605,
#   1610,
#   1615,
#   1617,
#   1621,
#   1629,
#   1630,
#   1634,
#   1636,
#   1638,
#   1639,
#   1641,
#   1642,
#   1643,
#   1644,
#   1646,
#   1649,
#   1650,
#   1654,
#   1656,
#   1660,
#   1663,
#   1674,
#   1675,
#   1678,
#   1687,
#   1690,
#   1716,
#   1717,
#   1718,
#   1719,
#   1723,
#   1725,
#   1727,
#   1729,
#   1730,
#   1733,
#   1736,
#   1737,
#   1738,
#   1739,
#   1741,
#   1742,
#   1743,
#   1747,
#   1748,
#   1749,
#   1750,
#   1756,
#   1757,
#   1758,
#   1759,
#   1760,
#   1761,
#   1763,
#   1767,
#   1769,
#   1770,
#   1773,
#   1776,
#   1777,
#   1778,
#   1781,
#   1785,
#   1786,
#   1788,
#   1789,
#   1794,
#   1795,
#   1798,
#   1801,
#   1802,
#   1804,
#   1806,
#   1807,
#   1811,
#   1813,
#   1814,
#   1815,
#   1816,
#   1822,
#   1824,
#   1825,
#   1828,
#   1829,
#   1830,
#   1832,
#   1834,
#   1836,
#   1837,
#   1841,
#   1848,
#   1854,
#   1855,
#   1857,
#   1859,
#   1861,
#   1889,
#   1890,
#   1892,
#   1893,
#   1896,
#   1906,
#   1908,
#   1909,
#   1910,
#   1911,
#   1917,
#   1938,
#   1947,
#   1950,
#   1954,
#   1956,
#   1959,
#   1962,
#   1967,
#   1968,
#   1969,
#   1974,
#   1981,
#   1984,
#   1991,
#   2000,
#   2009,
#   2010,
#   2013,
#   2018,
#   2019,
#   2022,
#   2027,
#   2033,
#   2034,
#   2035,
#   2036,
#   2038,
#   2048,
#   2050,
#   2053,
#   2055,
#   2056,
#   2057,
#   2058,
#   2059,
#   2064,
#   2065,
#   2066,
#   2067,
#   2068,
#   2070,
#   2071,
#   2072,
#   2073,
#   2074,
#   2077,
#   2078,
#   2099,
#   2100,
#   2103,
#   2108,
#   2109,
#   2110,
#   2113,
#   2120,
#   2121,
#   2122,
#   2130,
#   2131,
#   2132,
#   2137,
#   2138,
#   2146,
#   2147,
#   2153,
#   2155,
#   2157,
#   2158,
#   2159,
#   2160,
#   2161,
#   2162,
#   2165,
#   2175,
#   2176,
#   2177,
#   2178,
#   2182,
#   2184,
#   2186,
#   2187,
#   2188,
#   2189,
#   2192,
#   2193,
#   2196,
#   2203,
#   2212,
#   2213,
#   2214,
#   2215,
#   2218,
#   2222,
#   2224,
#   2232,
#   2235,
#   2239,
#   2243,
#   2244,
#   2245,
#   2248,
#   2250,
#   2253,
#   2254,
#   2255,
#   2257,
#   2258,
#   2259,
#   2260,
#   2261,
#   2263,
#   2266,
#   2271,
#   2273,
#   2274,
#   2289,
#   2290,
#   2294,
#   2296,
#   2299,
#   2300,
#   2301,
#   2302,
#   2303,
#   2304,
#   2308,
#   2312,
#   2313,
#   2314,
#   2316,
#   2317,
#   2318,
#   2321,
#   2322,
#   2324,
#   2328,
#   2332,
#   2334,
#   2335,
#   2348,
#   2353,
#   2355,
#   2395,
#   2464,
#   2475,
#   2483,
#   2487,
#   2488,
#   2492,
#   2495,
#   2512,
#   2516,
#   2517,
#   2521,
#   2530,
#   2531,
#   2533,
#   2535,
#   2538,
#   2539,
#   2542,
#   2548,
#   2549,
#   2550,
#   2554,
#   2555,
#   2556,
#   2558,
#   2560,
#   2561,
#   2562,
#   2563,
#   2566,
#   2571,
#   2581,
#   2582,
#   2583,
#   2584,
#   2588,
#   2590,
#   2591,
#   2592,
#   2593,
#   2615,
#   2617,
#   2619,
#   2620,
#   2622,
#   2623,
#   2624,
#   2625,
#   2626,
#   2627,
#   2628,
#   2629,
#   2632,
#   2639,
#   2642,
#   2643,
#   2645,
#   2651,
#   2652,
#   2653,
#   2657,
#   2658,
#   2660,
#   2661,
#   2664,
#   2668,
#   2670,
#   2671,
#   2672,
#   2673,
#   2674,
#   2677,
#   2678,
#   2683,
#   2688,
#   2690,
#   2692,
#   2693,
#   2694,
#   2697,
#   2700,
#   2702,
#   2703,
#   2705,
#   2706,
#   2707,
#   2710,
#   2717,
#   2719,
#   2720,
#   2729,
#   2731,
#   2733,
#   2735,
#   2736,
#   2737,
#   2741,
#   2742,
#   2743,
#   2744,
#   2746,
#   2752,
#   2760,
#   2767,
#   2770,
#   2771,
#   2773,
#   2774,
#   2775,
#   2776,
#   2778,
#   2779,
#   2780,
#   2782,
#   2783,
#   2784,
#   2796,
#   2798,
#   2799,
#   2801,
#   2806,
#   2811,
#   2812,
#   2815,
#   2819,
#   2820,
#   2821,
#   2859,
#   2876,
#   2879,
#   2887,
#   2890,
#   2891,
#   2892,
#   2893,
#   2895,
#   2896,
#   2898,
#   2902,
#   2903,
#   2904,
#   2906,
#   2908,
#   2911,
#   2916,
#   2917,
#   2934,
#   2936,
#   2937,
#   2947,
#   2954,
#   2956,
#   2961,
#   2972,
#   2978,
#   2979,
#   2982,
#   2984,
#   2990,
#   2992,
#   2995,
#   2997,
#   2998,
#   3000,
#   3008,
#   3020,
#   3021,
#   3026,
#   3028,
#   3029,
#   3030,
#   3032,
#   3033,
#   3034,
#   3035,
#   3039,
#   3040,
#   3043,
#   3045,
#   3047,
#   3048,
#   3052,
#   3053,
#   3054,
#   3055,
#   3060,
#   3064,
#   3067,
#   3070,
#   3071,
#   3073,
#   3074,
#   3075,
#   3077,
#   3078,
#   3081,
#   3082,
#   3090,
#   3094,
#   3097,
#   3098,
#   3105,
#   3106,
#   3107,
#   3110,
#   3113,
#   3115,
#   3117,
#   3119,
#   3122,
#   3123,
#   3135,
#   3141,
#   3145,
#   3149,
#   3155,
#   ...],
#  np.int32(1): [25,
#   165,
#   444,
#   633,
#   875,
#   1281,
#   2200,
#   2201,
#   2202,
#   4015,
#   4054,
#   4087,
#   4088,
#   4882,
#   4883,
#   5351,
#   6497,
#   7042,
#   7043,
#   7046,
#   7048,
#   8076,
#   10526,
#   11117,
#   30008,
#   55033,
#   56937,
#   79875,
#   81031],
#  np.int32(2): [2006,
#   2969,
#   3984,
#   5982,
#   6804,
#   7458,
#   7461,
#   8468,
#   9031,
#   9569,
#   26608,
#   84163,
#   84277,
#   114049,
#   135886,
#   155368,
#   155382,
#   653361]}

# %% [markdown]
# Funzione che calcola i GO/HPO caratteristici

# %%
def cluster_enrichment(binary_matrix, gene_list, top_k=10):
    """
    binary_matrix: DataFrame (geni × GOterms)
    gene_list: lista dei geni nel cluster
    """
    # subset cluster
    sub = binary_matrix.loc[gene_list]
    
    # frequenza nel cluster
    freq_cluster = sub.mean(axis=0)
    
    # frequenza totale
    freq_total = binary_matrix.mean(axis=0)
    
    # enrichment ratio
    enrichment = (freq_cluster + 1e-6) / (freq_total + 1e-6)
    
    # mettiamo tutto in un dataframe
    df = pd.DataFrame({
        "freq_cluster": freq_cluster,
        "freq_total": freq_total,
        "enrichment": enrichment
    })
    
    return df.sort_values("enrichment", ascending=False).head(top_k)

# %% [markdown]
# Calcolo dei GO terms caratteristici per ogni cluster

# %%
#Biological Process (BP)
for c in clusters:
    print(f"\n=== Cluster {c} — BP ===")
    print(cluster_enrichment(bp_filtered, clusters[c], top_k=10))


#Cellular Component (CC)
for c in clusters:
    print(f"\n=== Cluster {c} — CC ===")
    print(cluster_enrichment(cc_filtered, clusters[c], top_k=10))

#Molecular Function (MF)
for c in clusters:
    print(f"\n=== Cluster {c} — MF ===")
    print(cluster_enrichment(mf_filtered, clusters[c], top_k=10))
# Out:
# === Cluster 0 — BP ===
#             freq_cluster  freq_total  enrichment
# GO.0006629      0.088785    0.087980    1.009151
# GO.0030001      0.060358    0.059811    1.009151
# GO.0050801      0.051986    0.051515    1.009151
# GO.0055080      0.050623    0.050164    1.009151
# GO.0006954      0.044782    0.044376    1.009151
# GO.0006873      0.042835    0.042446    1.009151
# GO.0008610      0.042640    0.042254    1.009151
# GO.0030003      0.041667    0.041289    1.009151
# GO.0032787      0.040888    0.040517    1.009151
# GO.0044782      0.039914    0.039552    1.009151
#
# === Cluster 1 — BP ===
#             freq_cluster  freq_total  enrichment
# GO.0042704      0.068966    0.000386  178.264756
# GO.1902729      0.034483    0.000193  177.807743
# GO.1905006      0.034483    0.000193  177.807743
# GO.1905223      0.034483    0.000193  177.807743
# GO.0002651      0.034483    0.000193  177.807743
# GO.1905317      0.034483    0.000193  177.807743
# GO.0035906      0.034483    0.000193  177.807743
# GO.0021647      0.034483    0.000193  177.807743
# GO.1904531      0.034483    0.000193  177.807743
# GO.1904518      0.034483    0.000193  177.807743
#
# === Cluster 2 — BP ===
#             freq_cluster  freq_total  enrichment
# GO.2000234      0.055556    0.000193  286.464880
# GO.1905706      0.055556    0.000193  286.464880
# GO.1905213      0.055556    0.000193  286.464880
# GO.0014886      0.055556    0.000193  286.464880
# GO.0070476      0.055556    0.000193  286.464880
# GO.0010701      0.055556    0.000386  143.602667
# GO.0070475      0.055556    0.000386  143.602667
# GO.0141007      0.055556    0.000579   95.817668
# GO.1900264      0.055556    0.000579   95.817668
# GO.0010526      0.055556    0.000772   71.894250
#
# === Cluster 0 — CC ===
#             freq_cluster  freq_total  enrichment
# GO.0005759      0.047897    0.047463    1.009151
# GO.0016324      0.039330    0.038974    1.009151
# GO.0005774      0.037773    0.037430    1.009151
# GO.0005765      0.034852    0.034536    1.009151
# GO.0031253      0.034268    0.033957    1.009151
# GO.0098978      0.033879    0.033571    1.009151
# GO.0005819      0.030179    0.029905    1.009151
# GO.0030135      0.027259    0.027011    1.009151
# GO.0043292      0.027259    0.027011    1.009151
# GO.0030016      0.026480    0.026240    1.009151
#
# === Cluster 1 — CC ===
#             freq_cluster  freq_total  enrichment
# GO.0070021      0.068966    0.000386  178.264756
# GO.0071142      0.034483    0.000193  177.807743
# GO.0034668      0.034483    0.000193  177.807743
# GO.1990971      0.034483    0.000193  177.807743
# GO.0005586      0.034483    0.000193  177.807743
# GO.0001527      0.172414    0.001544  111.630911
# GO.0071144      0.068966    0.001158   59.524158
# GO.0032444      0.034483    0.000579   59.473690
# GO.0048179      0.034483    0.000772   44.624508
# GO.0032541      0.034483    0.000772   44.624508
#
# === Cluster 2 — CC ===
#             freq_cluster  freq_total  enrichment
# GO.0090535      0.055556    0.000193  286.464880
# GO.0031390      0.055556    0.000386  143.602667
# GO.0110016      0.055556    0.000579   95.817668
# GO.0070044      0.055556    0.000772   71.894250
# GO.0016281      0.055556    0.000772   71.894250
# GO.0071953      0.055556    0.000772   71.894250
# GO.0000813      0.055556    0.000965   57.530290
# GO.0032010      0.055556    0.000965   57.530290
# GO.0035371      0.055556    0.001544   35.970399
# GO.0043020      0.055556    0.001736   31.975988
#
# === Cluster 0 — MF ===
#             freq_cluster  freq_total  enrichment
# GO.0016788      0.045171    0.044762    1.009151
# GO.0015267      0.044782    0.044376    1.009151
# GO.0046873      0.040498    0.040131    1.009151
# GO.0005216      0.039525    0.039167    1.009151
# GO.0016746      0.037967    0.037623    1.009151
# GO.0005261      0.030763    0.030484    1.009151
# GO.0004175      0.024922    0.024696    1.009151
# GO.0030695      0.024338    0.024117    1.009151
# GO.0019787      0.021807    0.021609    1.009151
# GO.0001664      0.020444    0.020259    1.009151
#
# === Cluster 1 — MF ===
#             freq_cluster  freq_total  enrichment
# GO.0016941      0.068966    0.000386  178.264756
# GO.0070026      0.034483    0.000193  177.807743
# GO.0062101      0.034483    0.000193  177.807743
# GO.0046811      0.034483    0.000193  177.807743
# GO.0031962      0.034483    0.000193  177.807743
# GO.0004122      0.034483    0.000193  177.807743
# GO.0070025      0.034483    0.000193  177.807743
# GO.0034714      0.068966    0.000579  118.945655
# GO.0030023      0.103448    0.000965  107.124474
# GO.0032810      0.034483    0.000386   89.133671
#
# === Cluster 2 — MF ===
#             freq_cluster  freq_total  enrichment
# GO.0140801      0.055556    0.000193  286.464880
# GO.0016435      0.055556    0.000193  286.464880
# GO.0003689      0.055556    0.000386  143.602667
# GO.0019869      0.055556    0.000386  143.602667
# GO.0005528      0.055556    0.000579   95.817668
# GO.0016176      0.055556    0.000965   57.530290
# GO.0017081      0.055556    0.000965   57.530290
# GO.0030023      0.055556    0.000965   57.530290
# GO.0019855      0.055556    0.000965   57.530290
# GO.0016175      0.055556    0.000965   57.530290

# %% [markdown]
# Costruiamo il grafo dei geni

# %%
pip install networkx
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting networkx
#   Downloading networkx-3.2.1-py3-none-any.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 4.9 MB/s eta 0:00:01
# Installing collected packages: networkx
# Successfully installed networkx-3.2.1
# WARNING: You are using pip version 21.2.4; however, version 25.3 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import networkx as nx
import numpy as np

# 1) Usiamo solo i geni per cui abbiamo il cluster
genes = Z_clean.index
sim_sub = sim.loc[genes, genes]

# 2) Soglia di similarità per creare gli archi
THRESHOLD = 0.8  # puoi provare 0.6, 0.8, ecc.

G = nx.Graph()

# Aggiungo i nodi con attributo 'cluster'
for gene in genes:
    G.add_node(gene, cluster=int(Z_clean.loc[gene, "cluster"]))

# Aggiungo gli archi per similarità >= soglia
for i, g1 in enumerate(genes):
    for j in range(i+1, len(genes)):
        g2 = genes[j]
        w = sim_sub.loc[g1, g2]
        if w >= THRESHOLD:
            G.add_edge(g1, g2, weight=float(w))

print("Nodi nel grafo:", G.number_of_nodes())
print("Archi nel grafo (sim >= soglia):", G.number_of_edges())
# Out:
# Nodi nel grafo: 5183
# Archi nel grafo (sim >= soglia): 124078

# %%
import matplotlib.pyplot as plt

# Layout (può essere un po' lento se ci sono molti nodi)
pos = nx.spring_layout(G, seed=42, k=0.5)  # k controlla la distanza tra i nodi

# Costruisco una lista di colori per nodo in base al cluster
clusters = nx.get_node_attributes(G, "cluster")
unique_clusters = sorted(set(clusters.values()))

# palette semplice
colors_map = plt.cm.get_cmap("tab10", len(unique_clusters))
node_colors = [colors_map(clusters[node]) for node in G.nodes()]

plt.figure(figsize=(10, 8))

# Disegno archi
nx.draw_networkx_edges(
    G, pos,
    alpha=0.3,
    width=0.5
)

# Disegno nodi
nx.draw_networkx_nodes(
    G, pos,
    node_color=node_colors,
    node_size=25
)

# (Opzionale) niente label dei geni, altrimenti è illeggibile

# Legenda per i cluster (costruita a mano)
for c in unique_clusters:
    plt.scatter([], [], color=colors_map(c), label=f"Cluster {c}")
plt.legend(scatterpoints=1, frameon=False, title="Cluster")

plt.title(f"Network dei geni (sim >= {THRESHOLD})")
plt.axis("off")
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Layout Kamada-Kawai (più ordinato, edge-length più uniforme)
pos = nx.kamada_kawai_layout(G)

# Costruisco colori per cluster
clusters = nx.get_node_attributes(G, "cluster")
unique_clusters = sorted(set(clusters.values()))
colors_map = plt.cm.get_cmap("tab10", len(unique_clusters))
node_colors = [colors_map(clusters[node]) for node in G.nodes()]

plt.figure(figsize=(10, 8))

# Disegno archi
nx.draw_networkx_edges(
    G, pos,
    alpha=0.3,
    width=0.5
)

# Disegno nodi
nx.draw_networkx_nodes(
    G, pos,
    node_color=node_colors,
    node_size=25
)

# Legenda
for c in unique_clusters:
    plt.scatter([], [], color=colors_map(c), label=f"Cluster {c}")

plt.legend(scatterpoints=1, frameon=False, title="Cluster")
plt.title(f"Network dei geni (layout Kamada-Kawai, sim >= {THRESHOLD})")
plt.axis("off")
plt.tight_layout()
plt.show()

# %% [markdown]
# Grafo dei cluster (super compatto)

# %% [markdown]
# versione 2

# %%
THRESHOLD = 0.9  # puoi alzarlo/lowerarlo

G_full = nx.Graph()
genes = Z_clean.index
sim_sub = sim.loc[genes, genes]

# nodi
for gene in genes:
    G_full.add_node(gene, cluster=int(Z_clean.loc[gene, "cluster"]))

# archi
for i, g1 in enumerate(genes):
    for j in range(i+1, len(genes)):
        g2 = genes[j]
        w = sim_sub.loc[g1, g2]
        if w >= THRESHOLD:
            G_full.add_edge(g1, g2, weight=float(w))

# %%
N_GENES_PER_CLUSTER = 50

selected_genes = []

for c in sorted(Z_clean["cluster"].unique()):
    nodes_c = [n for n in G_full.nodes() if G_full.nodes[n]["cluster"] == c]
    
    # degree centrality
    degrees = {n: G_full.degree(n) for n in nodes_c}
    
    # prendi i top N
    top_nodes = sorted(degrees, key=degrees.get, reverse=True)[:N_GENES_PER_CLUSTER]
    
    selected_genes.extend(top_nodes)

len(selected_genes)


G_small = G_full.subgraph(selected_genes).copy()
print("Nodi nel grafo ridotto:", G_small.number_of_nodes())
print("Archi nel grafo ridotto:", G_small.number_of_edges())



plt.figure(figsize=(10,8))

pos = nx.spring_layout(G_small, seed=42, k=0.6)

clusters = nx.get_node_attributes(G_small, "cluster")
unique_clusters = sorted(set(clusters.values()))
palette = plt.cm.get_cmap("tab10", len(unique_clusters))

node_colors = [palette(clusters[n]) for n in G_small.nodes()]

# edges
nx.draw_networkx_edges(G_small, pos, alpha=0.3, width=0.6)

# nodes
nx.draw_networkx_nodes(
    G_small, pos,
    node_color=node_colors,
    node_size=120,
    edgecolors="black",
    linewidths=0.3
)

# labels facoltativi
# nx.draw_networkx_labels(G_small, pos, font_size=6)

# legenda
for c in unique_clusters:
    plt.scatter([], [], color=palette(c), label=f"Cluster {c}")
plt.legend(title="Cluster")

plt.title("Network dei geni (campionati) con cluster")
plt.axis("off")
plt.show()
# Out:
# Nodi nel grafo ridotto: 97
# Archi nel grafo ridotto: 988

# %% [markdown]
# K-MEANS

# %%
from sklearn.cluster import KMeans
import numpy as np

kmeans = KMeans(
    n_clusters=best_k,
    random_state=42,
    n_init=10
)

kmeans_labels = kmeans.fit_predict(Z_scaled)

# aggiungiamo i cluster K-means a Z_clean
Z_clean["kmeans_cluster"] = kmeans_labels

# distribuzione
unique, counts = np.unique(kmeans_labels, return_counts=True)
for c, n in zip(unique, counts):
    print(f"K-Means cluster {c}: {n} geni")
# Out:
# K-Means cluster 0: 4570 geni
# K-Means cluster 1: 29 geni
# K-Means cluster 2: 584 geni

# %% [markdown]
# visualizzazione umap con k-means

# %%
import matplotlib.pyplot as plt
import seaborn as sns

UMAP_df["kmeans_cluster"] = Z_clean["kmeans_cluster"]

plt.figure(figsize=(8,6))
sns.scatterplot(
    data=UMAP_df,
    x="UMAP1", y="UMAP2",
    hue="kmeans_cluster",
    palette="tab10",
    s=40
)

plt.title("UMAP — Clustering con K-Means", fontsize=14)
plt.xlabel("UMAP1")
plt.ylabel("UMAP2")
plt.legend(title="K-Means Cluster")
plt.show()

# %% [markdown]
# 🔵 3) Heatmap di similarità ordinata per cluster K-Means

# %%
# restrizione ai geni usati
sim_k = sim.loc[Z_clean.index, Z_clean.index]

# ordinamento per cluster K-Means
order_k = np.argsort(Z_clean["kmeans_cluster"].values)
genes_ordered_k = sim_k.index[order_k]

sim_ordered_k = sim_k.loc[genes_ordered_k, genes_ordered_k]

plt.figure(figsize=(6,6))
sns.heatmap(sim_ordered_k, cmap="magma", vmin=0, vmax=1)
plt.title("Matrice di similarità ordinata per cluster (K-Means)")
plt.show()

# %% [markdown]
# Confronto diretto: Spectral vs K-Means

# %%
comparison_df = Z_clean[["cluster", "kmeans_cluster"]].copy()
comparison_df
# Out:
#            cluster  kmeans_cluster
# 10               0               0
# 16               0               0
# 18               0               0
# 19               0               0
# 20               0               0
# ...            ...             ...
# 105371045        0               0
# 105804841        0               0
# 109580095        0               0
# 111365204        0               0
# 120766137        0               0
#
# [5183 rows x 2 columns]

# %%
pd.crosstab(
    comparison_df["cluster"],
    comparison_df["kmeans_cluster"],
    rownames=["Spectral"], 
    colnames=["K-Means"]
)
# Out:
# K-Means      0   1    2
# Spectral
# 0         4570   0  566
# 1            0  29    0
# 2            0   0   18

# %%
fig, axes = plt.subplots(1, 2, figsize=(14,6))

# Spectral
sns.scatterplot(
    ax=axes[0],
    data=UMAP_df,
    x="UMAP1", y="UMAP2",
    hue="cluster", palette="tab10",
    s=40
)
axes[0].set_title("UMAP — Spectral Clustering")
axes[0].legend(title="Spectral", bbox_to_anchor=(1,1))

# K-Means
sns.scatterplot(
    ax=axes[1],
    data=UMAP_df,
    x="UMAP1", y="UMAP2",
    hue="kmeans_cluster", palette="tab10",
    s=40
)
axes[1].set_title("UMAP — K-Means")
axes[1].legend(title="K-Means", bbox_to_anchor=(1,1))

plt.tight_layout()
plt.show()

# %% [markdown]
# LOGISTIC REGRESSION

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report
import numpy as np
import pandas as pd

# =======================
# DATA
# =======================

X = Z_scaled                     # fattori MOFA scaled
y = Z_clean["kmeans_cluster"].values    # target = cluster spectral

# =======================
# MODELLO LOGISTIC REGRESSION
# =======================

log_reg = LogisticRegression(
    multi_class="multinomial",
    solver="lbfgs",
    max_iter=500,
    random_state=42
)

log_reg.fit(X, y)

# =======================
# ACCURACY
# =======================
pred = log_reg.predict(X)
acc = accuracy_score(y, pred)

print(f"Accuracy Logistic Regression: {acc:.4f}\n")
print(classification_report(y, pred))
# Out:
# Accuracy Logistic Regression: 1.0000
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      4570
#            1       1.00      1.00      1.00        29
#            2       1.00      1.00      1.00       584
#
#     accuracy                           1.00      5183
#    macro avg       1.00      1.00      1.00      5183
# weighted avg       1.00      1.00      1.00      5183

# %% [markdown]
# Importanza dei fattori MOFA

# %%
coeffs = pd.DataFrame(
    log_reg.coef_,
    columns=[f"Factor_{i+1}" for i in range(X.shape[1])],
    index=[f"Cluster_{c}" for c in sorted(np.unique(y))]
)

coeffs
# Out:
#            Factor_1  Factor_2  Factor_3  Factor_4  Factor_5  Factor_6  \
# Cluster_0 -1.256348  1.847084  0.036891 -0.043927 -0.020042 -0.011825
# Cluster_1 -0.045244 -0.039467 -0.025993 -0.000867  0.027028  0.000481
# Cluster_2  1.301593 -1.807618 -0.010899  0.044794 -0.006985  0.011344
#
#            Factor_7  Factor_8  Factor_9  Factor_10  Factor_11  Factor_12  \
# Cluster_0 -0.176347 -0.016828 -0.458211   0.105736   0.026140  -0.015830
# Cluster_1  0.793528 -0.041222 -0.027757   0.018837   0.016109  -0.015205
# Cluster_2 -0.617181  0.058050  0.485969  -0.124573  -0.042249   0.031035
#
#            Factor_13  Factor_14  Factor_15
# Cluster_0   0.008010  -0.039770  -0.720407
# Cluster_1   0.000585   0.002951  -0.052619
# Cluster_2  -0.008595   0.036820   0.773026

# %%
# import seaborn as sns
# import matplotlib.pyplot as plt

# plt.figure(figsize=(10,6))
# sns.heatmap(coeffs, cmap="coolwarm", center=0, annot=True, fmt=".2f")
# plt.title("Importanza dei fattori MOFA (coefficients logistic regression)")
# plt.show()


import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))

ax = sns.heatmap(
    coeffs,
    cmap="coolwarm",
    center=0,
    annot=True,
    fmt=".2f"
)

# Titolo
plt.title("Importanza dei fattori MOFA (coefficients logistic regression)")

# Etichette assi
ax.set_xlabel("Factors", fontsize=12)
ax.set_ylabel("Clusters", fontsize=12)

# Se vuoi numerare i factors in stile Factor_1, Factor_2, ...
ax.set_xticklabels(
    [f"F{i+1}" for i in range(len(coeffs.columns))],
    rotation=45,
    ha="right"
)

# Numerazione dei clusters (Cluster_0, Cluster_1, ...)
ax.set_yticklabels(
    [f"Cl_{i}" for i in range(len(coeffs.index))],
    rotation=0
)

plt.tight_layout()
plt.show()

# %%
# import seaborn as sns
# import matplotlib.pyplot as plt
# import numpy as np

# plt.figure(figsize=(10,6))

# # Soglia sotto la quale NON mostriamo l'annotazione
# THRESH = 0.05

# # Prepariamo la matrice delle annotazioni
# annot_matrix = coeffs.copy().astype(str)

# for r in range(coeffs.shape[0]):
#     for c in range(coeffs.shape[1]):
#         if abs(coeffs.iloc[r,c]) < THRESH:
#             annot_matrix.iloc[r,c] = ""  # lascia vuoto
#         else:
#             annot_matrix.iloc[r,c] = f"{coeffs.iloc[r,c]:.2f}"

# # Heatmap con annotazioni filtrate
# ax = sns.heatmap(
#     coeffs,
#     cmap="coolwarm",
#     center=0,
#     annot=annot_matrix,
#     fmt="",
#     cbar=True
# )

# plt.title("Importanza dei fattori MOFA (coefficients logistic regression)")
# ax.set_xlabel("Factors", fontsize=12)
# ax.set_ylabel("Clusters", fontsize=12)

# ax.set_xticklabels(
#     [f"F{i+1}" for i in range(len(coeffs.columns))],
#     rotation=45,
#     ha="right"
# )

# ax.set_yticklabels(
#     [f"Cl_{i}" for i in range(len(coeffs.index))],
#     rotation=0
# )

# plt.tight_layout()
# plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# importanza media assoluta dei coefficienti
importance = coeffs.abs().mean(axis=0)

# ordina dal più importante al meno
importance_sorted = importance.sort_values(ascending=True)

plt.figure(figsize=(10,6))
plt.barh(importance_sorted.index, importance_sorted.values)
plt.xlabel("Importanza media (|coeff|)")
plt.title("Importanza dei fattori MOFA (Logistic Regression)")
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# ----------------------------
# 1. Importanza globale media
# ----------------------------
importance = coeffs.abs().mean(axis=0)

# Ordine globale (dal meno al più importante)
order = importance.sort_values(ascending=True).index

# Riordina i coeffs usando l'ordine globale
coeffs_sorted = coeffs[order].abs()

# ----------------------------
# 2. Parametri grafici
# ----------------------------
bar_height = 0.35        # barra più sottile
cluster_offset = 0.35     # distanza tra cluster sullo stesso factor
factor_spacing = 1.8      # distanza tra un factor e l'altro

clusters = coeffs_sorted.index
n_clusters = len(clusters)
n_factors = len(order)

# coordinate Y per i fattori (spaziati)
base_y = np.arange(n_factors) * factor_spacing

plt.figure(figsize=(12, 8))

for i, cluster in enumerate(clusters):
    plt.barh(
        y=base_y + i * cluster_offset,     # qui aumentiamo lo spazio tra cluster
        width=coeffs_sorted.loc[cluster],
        height=bar_height,
        label=f"Cluster {cluster}"
    )

plt.yticks(base_y + cluster_offset, order)

plt.xlabel("Importanza (|coeff|)")
plt.title("Importanza MOFA Factors per Cluster\n(spazio aumentato tra le barre dei cluster)")
plt.legend(title="Cluster", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# prova vis 3d

# %%
import numpy as np
import pandas as pd

# importanza globale media (assoluta) per fattore
importance = coeffs.abs().mean(axis=0)

# prendi i 3 fattori più importanti
top3 = importance.sort_values(ascending=False).index[:3]
print("Top 3 factors:", top3.tolist())
# Out:
# Top 3 factors: ['Factor_2', 'Factor_1', 'Factor_7']

# %%
# estrai i 3 fattori più importanti
f1, f2, f3 = top3

X3d = Z_clean[[f1, f2, f3]].values
labels = Z_clean["cluster"].values

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D  # necessario per 3D

# palette colori per i cluster
unique_clusters = np.sort(np.unique(labels))
colors_map = plt.cm.get_cmap("tab10", len(unique_clusters))
cluster_colors = [colors_map(c) for c in labels]

fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection="3d")

ax.scatter(
    X3d[:, 0], X3d[:, 1], X3d[:, 2],
    c=cluster_colors,
    s=30,
    alpha=0.9
)

ax.set_xlabel(f1)
ax.set_ylabel(f2)
ax.set_zlabel(f3)
ax.set_title("MOFA 3D embedding sui 3 fattori più importanti")

# legenda manuale
for c in unique_clusters:
    ax.scatter([], [], [], c=colors_map(c), label=f"Cluster {c}")
ax.legend(title="Cluster")

plt.tight_layout()
plt.show()

# %%
pip install plotly
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting plotly
#   Downloading plotly-6.5.0-py3-none-any.whl (9.9 MB)
#      |████████████████████████████████| 9.9 MB 11.5 MB/s eta 0:00:01
# Requirement already satisfied: packaging in /Users/edgardjossa/Library/Python/3.9/lib/python/site-packages (from plotly) (25.0)
# Collecting narwhals>=1.15.1
#   Downloading narwhals-2.12.0-py3-none-any.whl (425 kB)
#      |████████████████████████████████| 425 kB 17.4 MB/s eta 0:00:01
# Installing collected packages: narwhals, plotly
# Successfully installed narwhals-2.12.0 plotly-6.5.0
# WARNING: You are using pip version 21.2.4; however, version 25.3 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade nbformat
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting nbformat
#   Downloading nbformat-5.10.4-py3-none-any.whl (78 kB)
#      |████████████████████████████████| 78 kB 5.5 MB/s eta 0:00:011
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/edgardjossa/Library/Python/3.9/lib/python/site-packages (from nbformat) (5.8.1)
# Collecting fastjsonschema>=2.15
#   Downloading fastjsonschema-2.21.2-py3-none-any.whl (24 kB)
# Requirement already satisfied: jsonschema>=2.6 in /Users/edgardjossa/Library/Python/3.9/lib/python/site-packages (from nbformat) (4.24.0)
# Requirement already satisfied: traitlets>=5.1 in /Users/edgardjossa/Library/Python/3.9/lib/python/site-packages (from nbformat) (5.14.3)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/edgardjossa/Library/Python/3.9/lib/python/site-packages (from jsonschema>=2.6->nbformat) (0.25.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/edgardjossa/Library/Python/3.9/lib/python/site-packages (from jsonschema>=2.6->nbformat) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/edgardjossa/Library/Python/3.9/lib/python/site-packages (from jsonschema>=2.6->nbformat) (0.36.2)
# Requirement already satisfied: attrs>=22.2.0 in /Users/edgardjossa/Library/Python/3.9/lib/python/site-packages (from jsonschema>=2.6->nbformat) (25.3.0)
# Requirement already satisfied: platformdirs>=2.5 in /Users/edgardjossa/Library/Python/3.9/lib/python/site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (4.4.0)
# Requirement already satisfied: typing-extensions>=4.4.0 in /Users/edgardjossa/Library/Python/3.9/lib/python/site-packages (from referencing>=0.28.4->jsonschema>=2.6->nbformat) (4.14.0)
# Installing collected packages: fastjsonschema, nbformat
# Successfully installed fastjsonschema-2.21.2 nbformat-5.10.4
# WARNING: You are using pip version 21.2.4; however, version 25.3 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pipx install xyz
# Out:
#   Cell In[133], line 1
#     pipx install xyz
#          ^
# SyntaxError: invalid syntax

# %%
# !pip install ipywidgets
# Out:
# error: externally-managed-environment
#
# × This environment is externally managed
# ╰─> To install Python packages system-wide, try brew install
#     xyz, where xyz is the package you are trying to
#     install.
#
#     If you wish to install a Python library that isn't in Homebrew,
#     use a virtual environment:
#
#     python3 -m venv path/to/venv
#     source path/to/venv/bin/activate
#     python3 -m pip install xyz
#
#     If you wish to install a Python application that isn't in Homebrew,
#     it may be easiest to use 'pipx install xyz', which will manage a
#     virtual environment for you. You can install pipx with
#
#     brew install pipx
#
#     You may restore the old behavior of pip by passing
#     the '--break-system-packages' flag to pip, or by adding
#     'break-system-packages = true' to your pip.conf file. The latter
#     will permanently disable this error.
#
#     If you disable this error, we STRONGLY recommend that you additionally
#     pass the '--user' flag to pip, or set 'user = true' in your pip.conf
#     file. Failure to do this can result in a broken Homebrew installation.
#
#     Read more about this behavior here: <https://peps.python.org/pep-0668/>
#
# note: If you believe this is a mistake, please contact your Python installation or OS distribution provider. You can override this, at the risk of breaking your Python installation or OS, by passing --break-system-packages.
# hint: See PEP 668 for the detailed specification.

# %%
import plotly.express as px
import plotly.io as pio
pio.renderers.default = "browser"


# Costruiamo un DataFrame con solo i fattori che ci servono + cluster
plot_df = Z_clean[[f1, f2, f3, "kmeans_cluster"]].copy()
plot_df["gene"] = plot_df.index  # per mostrare il nome del gene in hover

fig = px.scatter_3d(
    plot_df,
    x=f1,
    y=f2,
    z=f3,
    color="kmeans_cluster",
    hover_name="gene",
    title=f"Embedding 3D MOFA sui 3 fattori più importanti ({f1}, {f2}, {f3})"
)

# Un po' di styling
fig.update_traces(marker=dict(size=4, opacity=0.8))
fig.update_layout(
    legend_title_text="Cluster",
    scene=dict(
        xaxis_title=f1,
        yaxis_title=f2,
        zaxis_title=f3
    )
)

fig.show()

# %%
import plotly.express as px
import plotly.io as pio
pio.renderers.default = "browser"

# cast del cluster a stringa per avere categorie
plot_df = Z_clean[[f1, f2, f3, "kmeans_cluster"]].copy()
plot_df["cluster_str"] = plot_df["kmeans_cluster"].astype(str)
plot_df["gene"] = plot_df.index  # per hover

fig = px.scatter_3d(
    plot_df,
    x=f1,
    y=f2,
    z=f3,
    color="cluster_str",
    hover_name="gene",
    title=f"Embedding 3D MOFA sui 3 fattori più importanti ({f1}, {f2}, {f3})",
    color_discrete_sequence=["#1f77b4", "#ff7f0e", "#2ca02c"]  # blu, arancione, verde
)

fig.update_traces(marker=dict(size=4, opacity=0.8))

fig.update_layout(
    legend_title_text="Cluster",
    scene=dict(
        xaxis_title=f1,
        yaxis_title=f2,
        zaxis_title=f3
    )
)

fig.show()

# %% [markdown]
# Boxplot dei fattori MOFA per cluster

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# ---------------------------------------
# Step 1: Identificare i 5 fattori più importanti
# ---------------------------------------

importance = coeffs.abs().mean(axis=0)
top5 = importance.sort_values(ascending=False).index[:5]
print("Top 5 factors:", top5.tolist())

# ---------------------------------------
# Step 2: Preparo dataframe con solo i fattori top 5
# ---------------------------------------

df_box = Z_clean.copy()
df_box["cluster"] = df_box["kmeans_cluster"].astype(str)

# ---------------------------------------
# Step 3: Un grafico con NOTCH per ogni fattore
# ---------------------------------------

for factor in top5:
    plt.figure(figsize=(8, 5))
    
    sns.boxplot(
        data=df_box,
        x="cluster",
        y=factor,
        palette="Set2",
        notch=True,   # ❤️ notch attivato
        linewidth=1.5
    )
    
    plt.title(f"Distribuzione del fattore {factor} nei cluster (con notches)")
    plt.xlabel("Cluster")
    plt.ylabel(factor)
    plt.tight_layout()
    plt.show()
# Out:
# Top 5 factors: ['Factor_2', 'Factor_1', 'Factor_7', 'Factor_15', 'Factor_9']
